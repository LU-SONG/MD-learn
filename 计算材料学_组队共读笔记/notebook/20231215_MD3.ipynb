# %% [markdown]
# ## 宋璐-第6天-周期性边界与近邻列表
# ### 学习笔记
# #### 周期性边界条件与近邻列表
# **为什么要用周期性边界条件？** → 真实体系总原子数10^24^，表面原子占比10^-8^，但是在盒子中1000个、10^6^原子体系表面（10%，1%）影响不可忽略 → 构建周期性边界条件，**消除表面效应** → 模拟体相性质
#
# #### 代码实现
#
# ```py
# # 边界位置
# position = (position - box.lower) % L + box.lowe
# ```
#
# #### 近邻列表
# 原则上，原子间相互作用无论间隔有多大，原子对之间的作用具有非零值。 实际上，发现对于像 Lennard-Jones这样的势能，一旦间距超过 σ 的几倍，原子间相互作用近似为零。
# 所以，与给定原子存在相互作用的近邻原子通常有限，可以用一个近邻列表来存储。
#
# • 检查粒子是否落在彼此的半径内
# • 只需偶尔重建近邻表
